# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from siamese_net import ActionAutoencoder, CardAutoencoder, PseudoSiameseNet
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 import torch.nn.functional as F
#
# File c:\Users\Mario\Documents\Git\pokAI\env\Lib\site-packages\torch\__init__.py:1798
#    1795 from torch._tensor import Tensor  # usort: skip
#    1797 # needs to be after torch.Tensor is defined to avoid circular dependencies
# -> 1798 from torch import storage as storage  # usort: skip
#    1799 from torch.storage import (
#    1800     _LegacyStorage,
#    1801     _StorageBase,
#    (...)
#    1804     UntypedStorage,
#    1805 )
#    1808 # NOTE: New <type>Storage classes should never be added. When adding a new
#    1809 # dtype, use torch.storage.TypedStorage directly.
#
# File c:\Users\Mario\Documents\Git\pokAI\env\Lib\site-packages\torch\storage.py:36
#      32 __all__ = ["TypedStorage", "UntypedStorage"]
#      35 try:
# ---> 36     import numpy as np
#      38     HAS_NUMPY = True
#      39 except ModuleNotFoundError:
#
# File c:\Users\Mario\Documents\Git\pokAI\env\Lib\site-packages\numpy\__init__.py:128
#     125 from . import _distributor_init
#     127 try:
# --> 128     from numpy.__config__ import show as show_config
#     129 except ImportError as e:
#     130     msg = """Error importing numpy: you should not try to import numpy from
#     131     its source directory; please exit the numpy source tree, and relaunch
#     132     your python interpreter from there."""
#
# File c:\Users\Mario\Documents\Git\pokAI\env\Lib\site-packages\numpy\__config__.py:4
#       1 # This file is generated by numpy's build process
#       2 # It contains system_info results at the time of building this package.
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show"]
#      11 _built_with_meson = True
#
# File c:\Users\Mario\Documents\Git\pokAI\env\Lib\site-packages\numpy\_core\__init__.py:23
#      20         env_added.append(envkey)
#      22 try:
# ---> 23     from . import multiarray
#      24 except ImportError as exc:
#      25     import sys
#
# File c:\Users\Mario\Documents\Git\pokAI\env\Lib\site-packages\numpy\_core\multiarray.py:10
#       1 """
#       2 Create the numpy._core.multiarray namespace for backward compatibility.
#       3 In v1.16 the multiarray and umath c-extension modules were merged into
#    (...)
#       6
#       7 """
#       9 import functools
# ---> 10 from . import overrides
#      11 from . import _multiarray_umath
#      12 from ._multiarray_umath import *  # noqa: F403
#
# File c:\Users\Mario\Documents\Git\pokAI\env\Lib\site-packages\numpy\_core\overrides.py:8
#       6 from .._utils import set_module
#       7 from .._utils._inspect import getargspec
# ----> 8 from numpy._core._multiarray_umath import (
#       9     add_docstring,  _get_implementing_args, _ArrayFunctionDispatcher)
#      12 ARRAY_FUNCTIONS = set()
#      14 array_function_like_doc = (
#      15     """like : array_like, optional
#      16         Reference object to allow the creation of arrays which are not
#    (...)
#      20         compatible with that passed in via this argument."""
#      21 )
#
# RuntimeError: CPU dispatcher tracer already initlized

# %%
action_data = torch.rand(32, 24, 4, 9)  # 32 samples
card_data   = torch.rand(32, 6, 4, 13)   # 32 samples

action_dataset = TensorDataset(action_data)
card_dataset = TensorDataset(card_data)
action_loader = DataLoader(action_dataset, batch_size=8)
card_loader = DataLoader(card_dataset, batch_size=8)

# Instantiate and train each autoencoder
action_autoencoder = ActionAutoencoder()
card_autoencoder = CardAutoencoder()

action_autoencoder.train_encoder(action_loader, num_epochs=10)
card_autoencoder.train_encoder(card_loader, num_epochs=10)

action_encoder = action_autoencoder.encoder
card_encoder = card_autoencoder.encoder 

siamese_net = PseudoSiameseNet(action_encoder, card_encoder)
